# %%
import importlib
import data_processing as dp

# %%
importlib.reload(dp)

# download the s3 data
dp.download_s3_data()

# Combine tables from files
games_df, odds_df = dp.combine_data()
# Out:
# Downloaded 166 files to: downloaded_files
# Combined games shape: (18, 5)
# Combined odds shape: (911, 6)

# %% [markdown]
# ### Plot odds

# %%
# Look at odds for game referenced by game_id
importlib.reload(dp)

# select games
game_id = odds_df.iloc[5]['GameID'] 

# fix up the datetime of that match
game_info, game_odds, start_time = dp.fix_datetime(game_id, games_df, odds_df)
dp.plot_odds_data(game_info, game_odds, start_time)
# Out:
# Date change occurred at row 81, total rows: 83

# %%
importlib.reload(dp)
total_bet = 100
result = dp.find_middle_strategy(game_info, game_odds, start_time, total_bet)

# print(f"Away max odds time: {result['away_time']}, Odds: {game_odds.loc[game_odds['DateTime'] == away_time, 'AwayOdds'].values[0]}")
# print(f"Home max odds time: {home_time}, Odds: {game_odds.loc[game_odds['DateTime'] == home_time, 'HomeOdds'].values[0]}")
print(f"Away max odds: {result['away_max_odds']:.2f}")
print(f"Home max odds: {result['home_max_odds']:.2f}")
print(f"Win ratio: {result['win_ratio']:.2f}")
print(f"Bet on away: ${result['b1']:.2f}")
print(f"Bet on home: ${result['b2']:.2f}")
print(f"Return if away wins: ${result['return_away_win']:.2f}")
print(f"Return if home wins: ${result['return_home_win']:.2f}")
# Out:
# Bet on away: $39.07
# Bet on home: $60.93
# Return if away wins: $29.32
# Return if home wins: $73.04
